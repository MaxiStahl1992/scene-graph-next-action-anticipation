# %% [markdown]
# # 02: Do relations help?
#
# The entity-history model and temporal graph model see the same anticipation events and
# the same five seconds of history. The presence or absence of graph relations is the
# comparison.

# %% [markdown]
# ## Conditions
#
# Implement the frequency/Markov baseline, entity GRU, temporal GNN and edge control with
# a shared training and selection protocol.

# %% [markdown]
# ## Validation
#
# Choose training duration using validation procedures only. Do not inspect test results
# while making modeling decisions.

# %% [markdown]
# ## Final comparison
#
# Report top-1, top-3 and mean reciprocal rank over three seeds. The primary result is the
# paired difference between the temporal GNN and entity GRU; the edge control determines
# whether relational structure accounts for that difference.

# %% [markdown]
# ## Findings
#
# *Written after the predefined experiment has been run.*

# %% [markdown]
# ## Limitations
#
# Interpret the result as a public-data mechanism study. Discuss CAT-SG pseudolabels,
# procedure specificity, the absence of surgeon identity and the gap to deployment.
