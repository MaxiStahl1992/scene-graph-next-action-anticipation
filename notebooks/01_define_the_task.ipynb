# %% [markdown]
# # 01: What exactly are we anticipating?
#
# This notebook turns CAT-SG's frame annotations into one leakage-safe anticipation task.
# The design is fixed before any model is trained.

# %% [markdown]
# ## The data
#
# Describe the procedures, entities, instruments and relation types relevant to the task.
# Separate descriptive checks on training, validation and test procedures.

# %% [markdown]
# ## From frames to anticipation events
#
# Define an event, its five-second observation window and the fixed three-second forecast
# gap. Verify that the target instrument is absent throughout every model input.

# %% [markdown]
# ## Is the task learnable?
#
# Measure event counts, class imbalance and split coverage before fitting a neural model.
# Freeze the eligible instrument vocabulary using training data only.

# %% [markdown]
# ## Locked evaluation protocol
#
# Record the final cohort, baselines, metrics, seeds and falsification rule consumed by
# notebook 02.
